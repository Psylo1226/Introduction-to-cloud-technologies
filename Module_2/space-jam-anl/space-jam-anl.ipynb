# %%
import pandas as pd

# %%
player_df_final = pd.read_csv('player_data_final.csv')

# %%
# Create a DataFrame of only Tune Squad players.
ts_df = player_df_final.iloc[26: , :]
ts_df
# Out:
#     ID        player  points  possessions  team_pace         GP        MPG  \
# 26  31   tune_squad1  2049.0       1434.0      110.0  64.000000  38.800000
# 27  32   tune_squad2  1795.0       1481.8      112.1  62.000000  35.400000
# 28  33   tune_squad3  1805.0       1509.9      108.6  64.000000  35.400000
# 29  34   tune_squad4  1743.0       1422.4      112.9  64.000000  36.300000
# 30  35   tune_squad5  1963.0       1539.1      117.4  59.771429  35.208333
# 31  36   tune_squad6  2062.0       1505.7      111.5  59.771429  37.000000
# 32  37   tune_squad7  1845.0       1435.7      113.1  69.000000  36.900000
# 33  38   tune_squad8  1778.0       1526.4      109.3  66.000000  34.900000
# 34  39   tune_squad9  1901.0       1444.1      109.7  67.000000  36.500000
# 35  41  tune_squad11  2030.0       1431.0      112.3  68.000000  37.000000
# 36  42  tune_squad12  1631.0       1465.7      110.1  66.000000  37.500000
# 37  43  tune_squad13  1828.0       1507.2      112.7  64.000000  36.500000
# 38  44  tune_squad14  1821.0       1443.7      118.8  66.000000  36.600000
# 39  45  tune_squad15  1740.0       1443.9      114.1  68.000000  37.100000
# 40  46  tune_squad16  1993.0       1459.0      112.5  59.771429  36.900000
#
#       TS%   AST    TO   USG  ORR   DRR  REBR        PER
# 26  0.619  31.5  14.9  35.5  8.3  17.6  12.8  28.440000
# 27  0.608  31.9  14.5  32.0  6.5  22.5  12.9  23.340000
# 28  0.622  27.9  13.9  36.0  5.9  27.7  12.2  22.410000
# 29  0.619  30.9  15.6  34.5  5.9  18.9  14.8  29.853138
# 30  0.633  32.3  16.2  34.0  5.9  19.8  13.1  27.160000
# 31  0.620  29.8  15.6  36.2  4.9  23.9  14.7  27.860000
# 32  0.634  33.2  14.0  36.5  4.1  21.5  16.4  34.260000
# 33  0.612  30.6  15.9  35.9  5.5  18.8  13.7  28.650000
# 34  0.609  27.2  14.8  35.5  5.0  21.8   8.9  20.120000
# 35  0.618  32.5  15.3  34.5  5.7  15.7  13.2  30.070000
# 36  0.613  28.4  14.4  35.7  6.5  20.7  14.0  28.400000
# 37  0.618  31.3  14.0  34.9  5.9  21.3  14.5  29.094310
# 38  0.609  27.3  13.5  35.8  7.0  23.8  11.5  22.960000
# 39  0.611  26.6  15.2  29.3  8.3  17.7  11.1  21.220000
# 40  0.627  30.4  15.0  33.7  6.3  19.3  14.1  28.760000

# %%
ts_name_df = pd.read_csv('tune_squad.csv', sep='\t')
ts_name_df
# Out:
#     ID              player
# 0   31           Sylvester
# 1   32  Marvin the Martian
# 2   33         Road Runner
# 3   34     Foghorn Leghorn
# 4   35          Bugs Bunny
# 5   36          Elmer Fudd
# 6   37          Lola Bunny
# 7   38           Porky Pig
# 8   39     Tasmanian Devil
# 9   40        Yosemite Sam
# 10  41            Gossamer
# 11  42              Granny
# 12  43      Wile E. Coyote
# 13  44              Tweety
# 14  45            Penelope
# 15  46          Daffy Duck

# %%
ts_df = pd.merge(ts_df, ts_name_df, on='ID', how='left', suffixes=('_type', '_name'))
ts_df.head()
# Out:
#    ID  player_type  points  possessions  team_pace         GP        MPG  \
# 0  31  tune_squad1  2049.0       1434.0      110.0  64.000000  38.800000
# 1  32  tune_squad2  1795.0       1481.8      112.1  62.000000  35.400000
# 2  33  tune_squad3  1805.0       1509.9      108.6  64.000000  35.400000
# 3  34  tune_squad4  1743.0       1422.4      112.9  64.000000  36.300000
# 4  35  tune_squad5  1963.0       1539.1      117.4  59.771429  35.208333
#
#      TS%   AST    TO   USG  ORR   DRR  REBR        PER         player_name
# 0  0.619  31.5  14.9  35.5  8.3  17.6  12.8  28.440000           Sylvester
# 1  0.608  31.9  14.5  32.0  6.5  22.5  12.9  23.340000  Marvin the Martian
# 2  0.622  27.9  13.9  36.0  5.9  27.7  12.2  22.410000         Road Runner
# 3  0.619  30.9  15.6  34.5  5.9  18.9  14.8  29.853138     Foghorn Leghorn
# 4  0.633  32.3  16.2  34.0  5.9  19.8  13.1  27.160000          Bugs Bunny

# %%
# Rearrange the columns to put the ID and player_name columns next to each other.
column_list = list(ts_df)

player_name = column_list.pop()
column_list[1] = player_name

ts_df = ts_df[column_list]
ts_df.head()
# Out:
#    ID         player_name  points  possessions  team_pace         GP  \
# 0  31           Sylvester  2049.0       1434.0      110.0  64.000000
# 1  32  Marvin the Martian  1795.0       1481.8      112.1  62.000000
# 2  33         Road Runner  1805.0       1509.9      108.6  64.000000
# 3  34     Foghorn Leghorn  1743.0       1422.4      112.9  64.000000
# 4  35          Bugs Bunny  1963.0       1539.1      117.4  59.771429
#
#          MPG    TS%   AST    TO   USG  ORR   DRR  REBR        PER
# 0  38.800000  0.619  31.5  14.9  35.5  8.3  17.6  12.8  28.440000
# 1  35.400000  0.608  31.9  14.5  32.0  6.5  22.5  12.9  23.340000
# 2  35.400000  0.622  27.9  13.9  36.0  5.9  27.7  12.2  22.410000
# 3  36.300000  0.619  30.9  15.6  34.5  5.9  18.9  14.8  29.853138
# 4  35.208333  0.633  32.3  16.2  34.0  5.9  19.8  13.1  27.160000

# %%
# Create a list of only the column names we're interested in.
game_stat_cols = list(ts_df.iloc[:, 7:-1])
game_stat_stdevs = []

# Create a list of standard deviations for each stat.
for stat in game_stat_cols:
    game_stat_stdevs.append(ts_df[stat].std())

# Create a Series of the standard deviations, with the stat names as the index.
stdev_s = pd.Series(game_stat_stdevs, index=game_stat_cols)
stdev_s
# Out:
# TS%     0.008262
# AST     2.140494
# TO      0.797197
# USG     1.892718
# ORR     1.139465
# DRR     3.017962
# REBR    1.802564
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from numpy.random import randn

# Get the dependent and independent variables for modeling the PER.
X = player_df_final.iloc[:, 7:-1].to_numpy()
y = player_df_final.iloc[:, -1]

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
print('Iteration # \thigh PER \tlow PER')

# Run the simulation 10 times.
for i in range(10):

    # Define an empty temporary DataFrame for each iteration.
    # The columns of this DataFrame are the player stats and the index is the players' names.
    game_df = pd.DataFrame(columns=game_stat_cols, index=list(ts_df['player_name']))

    # Loop through each stat.
    for stat in game_stat_cols:

        # Each player's stats are used to generate a random value for each iteration.
        game_df[stat] = list(ts_df[stat] + randn(len(ts_df)) * stdev_s[stat])

    # Use the fitted model to predict players' PERs based on the randomized data.
    game_df['PER'] = lin_reg.predict(game_df)

     # Print the player with the highest and lower PER for each iteration.
    print('Iteration {}'.format(i+1) + ' \t' + game_df['PER'].idxmax() + ' \t' + game_df['PER'].idxmin())
# Out:
# Iteration # 	high PER 	low PER
# Iteration 1 	Lola Bunny 	Road Runner
# Iteration 2 	Lola Bunny 	Tasmanian Devil
# Iteration 3 	Gossamer 	Penelope
# Iteration 4 	Lola Bunny 	Penelope
# Iteration 5 	Lola Bunny 	Penelope
# Iteration 6 	Wile E. Coyote 	Penelope
# Iteration 7 	Gossamer 	Tasmanian Devil
# Iteration 8 	Lola Bunny 	Tasmanian Devil
# Iteration 9 	Elmer Fudd 	Penelope
# Iteration 10 	Foghorn Leghorn 	Tasmanian Devil
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
# Initialize four empty DataFrames, one for each 12-minute period.
number_of_iterations = 4
df_list = [pd.DataFrame(columns=game_stat_cols, index=list(ts_df['player_name'])) for i in range(number_of_iterations)]

# For each period, generate randomized player data and predict the PER.
# Use the model fitted earlier.
for df in df_list:
    for stat in game_stat_cols:
        df[stat] = list(ts_df[stat] + randn(len(ts_df)) * stdev_s[stat])
    df['PER'] = lin_reg.predict(df)

game_df = pd.concat(df_list)
game_df.rename_axis('player_name', inplace=True)

# Create another index for the period in question.
minutes = [(x // len(ts_df)) * 12 for x in range(len(game_df))]
game_df['minutes'] = minutes
game_df.set_index('minutes', append=True, inplace=True)
game_df = game_df.swaplevel()

game_df
# Out:
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# c:\Users\KamilSarzyniak\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
#                                  TS%        AST         TO        USG  \
# minutes player_name
# 0       Sylvester           0.612851  33.558310  15.011142  35.547780
#         Marvin the Martian  0.608903  30.295366  14.535234  35.248583
#         Road Runner         0.623859  24.726251  13.507175  31.499514
#         Foghorn Leghorn     0.609329  30.503511  15.692646  34.490241
#         Bugs Bunny          0.629178  28.156635  16.403688  34.794410
#         Elmer Fudd          0.622535  30.350704  15.016706  36.461327
#         Lola Bunny          0.633795  30.930366  13.713779  38.044384
#         Porky Pig           0.628184  34.720175  15.080160  39.123559
#         Tasmanian Devil     0.607714  23.212008  14.902505  33.593256
#         Gossamer            0.607976  34.264964  16.821592  34.074184
#         Granny              0.618782  21.729425  13.202063  33.540206
#         Wile E. Coyote      0.615786  28.875330  14.508057  33.156171
#         Tweety              0.629259  24.781908  13.328171  36.095394
#         Penelope            0.605456  25.150140  15.708988  32.336498
#         Daffy Duck          0.633229  29.075593  15.488381  35.916589
# 12      Sylvester           0.609538  34.885742  14.494385  39.343038
#         Marvin the Martian  0.602237  29.616658  14.487037  31.061743
#         Road Runner         0.618750  26.628415  13.706890  37.530176
#         Foghorn Leghorn     0.625284  31.703409  15.761247  33.961953
#         Bugs Bunny          0.636135  32.008499  16.412850  34.737428
#         Elmer Fudd          0.607792  30.425951  15.407858  36.420952
#         Lola Bunny          0.635059  32.249237  15.588258  38.329242
#         Porky Pig           0.612406  30.857832  15.756426  34.669187
#         Tasmanian Devil     0.607138  27.595077  13.485258  33.775372
#         Gossamer            0.609254  34.447985  14.168017  35.929003
#         Granny              0.616450  28.796204  13.397452  33.869754
#         Wile E. Coyote      0.623496  31.893313  14.387538  36.063662
#         Tweety              0.621673  26.765231  14.943667  36.752461
#         Penelope            0.604950  26.845649  15.085115  32.066861
#         Daffy Duck          0.627218  30.468073  15.198992  30.544421
# 24      Sylvester           0.627572  32.255556  13.772820  36.217577
#         Marvin the Martian  0.602296  30.880601  15.230718  30.073576
#         Road Runner         0.623057  26.901069  13.029234  34.047436
#         Foghorn Leghorn     0.626981  26.801481  14.912268  34.326521
#         Bugs Bunny          0.632214  35.938348  16.557157  34.049213
#         Elmer Fudd          0.613290  27.360157  16.149306  36.861791
#         Lola Bunny          0.639327  33.704130  14.044009  38.426196
#         Porky Pig           0.617288  30.285669  15.056122  35.461738
#         Tasmanian Devil     0.607199  29.317292  13.786754  38.441573
#         Gossamer            0.604876  30.475837  14.088675  37.460909
#         Granny              0.606186  26.459354  13.827722  37.330046
#         Wile E. Coyote      0.616054  30.666557  12.602299  35.179761
#         Tweety              0.603117  28.719441  12.229745  36.013913
#         Penelope            0.606736  26.096128  14.485516  25.698669
#         Daffy Duck          0.620539  30.406068  14.932995  35.228369
# 36      Sylvester           0.622571  31.126945  15.863060  32.588237
#         Marvin the Martian  0.609210  29.591533  13.384409  29.463404
#         Road Runner         0.631788  26.079707  14.489605  37.215948
#         Foghorn Leghorn     0.617174  28.544561  15.078757  33.467844
#         Bugs Bunny          0.619934  31.026192  16.092515  34.239144
#         Elmer Fudd          0.614277  26.699412  16.189522  36.423436
#         Lola Bunny          0.629445  32.657328  14.196371  37.825336
#         Porky Pig           0.601243  26.808524  14.521895  35.554856
#         Tasmanian Devil     0.618018  26.074275  14.530753  35.854448
#         Gossamer            0.615375  31.979486  14.605529  33.794731
#         Granny              0.604848  30.426188  14.610251  33.603140
#         Wile E. Coyote      0.604066  31.943735  14.471258  38.628412
#         Tweety              0.608556  29.111587  14.556223  36.953790
#         Penelope            0.598226  25.760374  14.518287  30.836917
#         Daffy Duck          0.636499  28.191056  16.915804  32.091364
#
#                                   ORR        DRR       REBR        PER
# minutes player_name
# 0       Sylvester            8.301481  12.889777  11.469299  29.220334
#         Marvin the Martian   5.719030  24.462781  14.713928  26.743299
#         Road Runner          4.420136  28.477084  11.176357  18.302361
#         Foghorn Leghorn      7.594083  14.849483  13.159655  29.016817
#         Bugs Bunny           4.981954  22.066703  11.965732  24.231024
#         Elmer Fudd           4.765884  21.576581  17.585625  33.997107
#         Lola Bunny           5.243078  19.299037  15.443317  34.685604
#         Porky Pig            6.045528  20.154365  14.161996  32.115405
#         Tasmanian Devil      3.629615  26.077058   7.466311  14.247334
#         Gossamer             7.155946  22.531522  13.793005  24.663199
#         Granny               6.772551  15.819413  14.403913  30.840855
#         Wile E. Coyote       5.542871  12.723846  13.734378  31.713612
#         Tweety               7.114616  27.283753  10.873476  21.110235
#         Penelope             5.651733  21.166183  12.400476  22.491487
#         Daffy Duck           7.353567  15.115248  17.076033  36.537578
# 12      Sylvester            9.330245  24.045304   9.759556  22.181124
#         Marvin the Martian   5.203281  17.833244  15.853335  29.633494
#         Road Runner          6.310820  24.345750  15.725198  30.098485
#         Foghorn Leghorn      4.737628  15.771959  13.120327  29.780066
#         Bugs Bunny           4.518035  17.982193  15.712451  32.814314
#         Elmer Fudd           5.581994  24.198169  15.129749  27.685344
#         Lola Bunny           4.430924  25.364793  15.985262  31.214194
#         Porky Pig            3.907632  23.980492  14.407318  26.299802
#         Tasmanian Devil      3.768358  20.819127   8.205324  19.790928
#         Gossamer             7.290280  13.874956  15.206914  34.631942
#         Granny               7.733999  18.649791  14.971677  30.285318
#         Wile E. Coyote       5.473726  17.409104  12.049657  29.034649
#         Tweety               8.716727  23.477215   9.836359  20.884488
#         Penelope            10.428711  18.878004  10.538943  20.449050
#         Daffy Duck           5.568920  19.119880  15.578100  29.163342
# 24      Sylvester            7.218074  17.881093  12.695446  29.902614
#         Marvin the Martian   7.619710  16.462753  11.142152  22.458442
#         Road Runner          6.215016  25.495440  11.874718  22.628362
#         Foghorn Leghorn      4.966439  19.721664  13.659356  28.329255
#         Bugs Bunny           6.397737  25.319345  12.340064  22.786902
#         Elmer Fudd           6.149475  26.001592  13.922907  24.613855
#         Lola Bunny           4.466325  19.687874  14.475222  33.928843
#         Porky Pig            4.655199  21.282933  13.129175  27.094938
#         Tasmanian Devil      6.414727  18.863128   8.415929  23.430749
#         Gossamer             4.374025  22.788699   9.790849  22.646252
#         Granny               5.402695  20.634324  12.178708  26.783384
#         Wile E. Coyote       4.127705  23.116194  15.163099  30.077964
#         Tweety               8.121019  27.154521  13.007144  23.359812
#         Penelope             8.220230  17.353250  13.657865  22.824244
#         Daffy Duck           6.555515  15.554434  13.174982  30.355648
# 36      Sylvester            8.096410  19.860015  12.147652  23.963611
#         Marvin the Martian   7.511192  22.640438  12.221427  21.085338
#         Road Runner          6.888422  24.524797  11.636936  24.232764
#         Foghorn Leghorn      5.397972  16.349529  11.727955  26.634792
#         Bugs Bunny           4.818816  19.308868  10.438197  23.456178
#         Elmer Fudd           3.793340  24.640557  16.821535  29.778265
#         Lola Bunny           4.975995  25.612827  19.010805  35.316100
#         Porky Pig            6.602506  18.487603   9.591110  22.523573
#         Tasmanian Devil      4.545926  24.983123   7.507518  17.181712
#         Gossamer             5.223577  14.632917  13.010608  30.216678
#         Granny               7.639559  16.799690  15.359617  30.658909
#         Wile E. Coyote       5.495637  16.811975  13.709657  32.091360
#         Tweety               7.056124  23.915816  11.884209  23.692107
#         Penelope             8.678169  14.446807   8.779867  20.280493
#         Daffy Duck           5.374002  18.393617  12.318321  25.413768

# %%
game_df.to_csv('game_stats.csv')
